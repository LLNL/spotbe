# %%
import sys
import platform

machine = platform.uname().machine

# Variables replaced by spot.py
input_deploy_dir_str="SPOT_DEPLOY_DIR"
input_db_uri_str="SPOT_SPOTDB_URI"
input_run_ids_str="SPOT_SPOTDB_RECORD_IDS"

sys.path.append(input_deploy_dir_str+"/hatchet/" + machine)
sys.path.append(input_deploy_dir_str+"/spotdb")

import datetime as dt
import hatchet
import spotdb

db=spotdb.connect(input_db_uri_str)
runs=input_run_ids_str.split(',')

gfs=hatchet.GraphFrame.from_spotdb(db, runs)

for idx, gf in enumerate(gfs):
    launchdate = dt.datetime.fromtimestamp(int(gf.metadata["launchdate"]))
    jobsize = int(gf.metadata.get("jobsize", 1))
    print("launchdate: {}, jobsize: {}".format(launchdate, jobsize))
    print(gf.tree())
# Out:
# Run 0 jobsize: 1 launchdate: 2020-09-24 16:39:34
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.3.1a0
#
# 14.177 main
# └─ 14.167 lulesh.cycle
#    ├─ 14.141 LagrangeLeapFrog
#    │  ├─ 0.164 CalcTimeConstraintsForElems
#    │  ├─ 6.812 LagrangeElements
#    │  │  ├─ 4.993 ApplyMaterialPropertiesForElems
#    │  │  │  └─ 4.907 EvalEOSForElems
#    │  │  │     └─ 3.362 CalcEnergyForElems
#    │  │  ├─ 0.963 CalcLagrangeElements
#    │  │  │  └─ 0.914 CalcKinematicsForElems
#    │  │  └─ 0.823 CalcQForElems
#    │  │     └─ 0.298 CalcMonotonicQForElems
#    │  └─ 7.145 LagrangeNodal
#    │     └─ 7.029 CalcForceForNodes
#    │        └─ 6.994 CalcVolumeForceForElems
#    │           ├─ 5.117 CalcHourglassControlForElems
#    │           │  └─ 2.380 CalcFBHourglassForceForElems
#    │           └─ 1.796 IntegrateStressForElems
#    └─ 0.009 TimeIncrement
#
# Legend (Metric: Total time (inc) Min: 0.01 Max: 14.18)
# █ 12.76 - 14.18
# █ 9.93 - 12.76
# █ 7.09 - 9.93
# █ 4.26 - 7.09
# █ 1.43 - 4.26
# █ 0.01 - 1.43
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
#
# Run 1 jobsize: 1 launchdate: 2020-09-24 16:40:02
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.3.1a0
#
# 14.579 main
# └─ 14.570 lulesh.cycle
#    ├─ 14.536 LagrangeLeapFrog
#    │  ├─ 0.171 CalcTimeConstraintsForElems
#    │  ├─ 7.097 LagrangeElements
#    │  │  ├─ 5.283 ApplyMaterialPropertiesForElems
#    │  │  │  └─ 5.196 EvalEOSForElems
#    │  │  │     └─ 3.534 CalcEnergyForElems
#    │  │  ├─ 0.971 CalcLagrangeElements
#    │  │  │  └─ 0.922 CalcKinematicsForElems
#    │  │  └─ 0.810 CalcQForElems
#    │  │     └─ 0.281 CalcMonotonicQForElems
#    │  └─ 7.249 LagrangeNodal
#    │     └─ 7.135 CalcForceForNodes
#    │        └─ 7.100 CalcVolumeForceForElems
#    │           ├─ 5.194 CalcHourglassControlForElems
#    │           │  └─ 2.403 CalcFBHourglassForceForElems
#    │           └─ 1.835 IntegrateStressForElems
#    └─ 0.009 TimeIncrement
#
# Legend (Metric: Total time (inc) Min: 0.01 Max: 14.58)
# █ 13.12 - 14.58
# █ 10.21 - 13.12
# █ 7.29 - 10.21
# █ 4.38 - 7.29
# █ 1.47 - 4.38
# █ 0.01 - 1.47
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
